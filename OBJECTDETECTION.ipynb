# %% [markdown]
# <a href="https://colab.research.google.com/github/Rumman2022/First_pyg_walker/blob/main/OBJECTDETECTION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
car="/content/010.jpg"
cat = "/content/cat.jpg"

# %%
lion="/content/lion.jpg"

# %%
person = "/content/person.jpg"

# %%
tree = "/content/tree1.jpg"

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 625.9/625.9 kB 26.7 MB/s eta 0:00:00
# ...

# %%
# !yolo task=detect mode=predict model=yolov8n.pt source="/content/010.jpg"
# Out:
# Ultralytics YOLOv8.0.128 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients
#
# image 1/1 /content/010.jpg: 448x640 4 cars, 3 trucks, 62.8ms
# Speed: 11.2ms preprocess, 62.8ms inference, 17.0ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict

# %%
from IPython.display import Image

# %% [markdown]
# original image

# %%
Image(car)

# %% [markdown]
# predicted image

# %%
Image("/content/runs/detect/predict/010.jpg")

# %% [markdown]
# original image of tree

# %%
Image(tree)

# %% [markdown]
# predicted image of tree

# %%
# !yolo task=detect mode=predict model=yolov8n.pt source="/content/tree1.jpg"
# Out:
# Ultralytics YOLOv8.0.128 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients
#
# image 1/1 /content/tree1.jpg: 448x640 5 cars, 69.9ms
# Speed: 3.1ms preprocess, 69.9ms inference, 1.8ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict7

# %%
Image("/content/runs/detect/predict7/tree1.jpg")

# %% [markdown]
# original image of persons

# %%
Image("/content/person.jpg")

# %% [markdown]
# predicted image of person

# %%
# !yolo task=detect mode=predict model=yolov8n.pt source="/content/person.jpg"
# Out:
# Ultralytics YOLOv8.0.128 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients
#
# image 1/1 /content/person.jpg: 448x640 1 person, 3 cars, 1 bus, 1 tie, 1 chair, 73.3ms
# Speed: 3.3ms preprocess, 73.3ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict3

# %%
Image("/content/runs/detect/predict3/person.jpg")

# %% [markdown]
# original image of animal

# %%
Image(cat)

# %% [markdown]
# predicted image of animal

# %%
# !yolo task=detect mode=predict model=yolov8n.pt source="/content/cat.jpg"
# Out:
# Ultralytics YOLOv8.0.128 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients
#
# image 1/1 /content/cat.jpg: 640x640 1 cat, 9.0ms
# Speed: 3.1ms preprocess, 9.0ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict6

# %%
Image("/content/runs/detect/predict6/cat.jpg")

# %% [markdown]
# hi careeraera team
#
# as of now my object detection case study is going well, i found among all of the models yolo8 is fast and 85 to 90 percentage accuracy... there for i have used yolov8n model to predict my output classes i found i could not predict trees and all other classes being predicted correctly, therefore i am still more focused on other models aswell,
#
# thanks
# Rumman
